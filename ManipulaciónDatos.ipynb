# %% [markdown]
# ## 🐍 Manipulación de Datos
# ### 👤 Desarrollado por: Nancy Borges

# %%
import pandas as pd 
import numpy as np
import datetime as dt

# %% [markdown]
# ###  📂  Exploración Inicial
# *Uso de head(), tail(), info() y describe() para entender la estructura.*

# %%
#carga de datos
df= pd.read_csv(r'C:\Users\Outlet\Desktop\Nueva carpeta\NorthWind.csv',sep=',',header=0, index_col=False, encoding='latin-1',engine='python')

#muestra las primeras 5 filas
df.head()
# Out:
#                ShipName    ShipAddress ShipCity ShipRegion ShipPostalCode  \
# 0  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# 1  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# 2  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# 3  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# 4  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
#
#   ShipCountry CustomerID         CustomerName CustomerAddress CustomerCity  \
# 0     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 1     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 2     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 3     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 4     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
#
# ...

# %%
#muestra las últimas filas
df.tail()
# Out:
#                   ShipName          ShipAddress ShipCity ShipRegion  \
# 2150  White Clover Markets  1029 - 12th Ave. S.  Seattle         WA
# 2151  White Clover Markets  1029 - 12th Ave. S.  Seattle         WA
# 2152  White Clover Markets  1029 - 12th Ave. S.  Seattle         WA
# 2153  White Clover Markets  1029 - 12th Ave. S.  Seattle         WA
# 2154  White Clover Markets  1029 - 12th Ave. S.  Seattle         WA
#
#      ShipPostalCode ShipCountry CustomerID          CustomerName  \
# 2150          98124         USA      WHITC  White Clover Markets
# 2151          98124         USA      WHITC  White Clover Markets
# 2152          98124         USA      WHITC  White Clover Markets
# 2153          98124         USA      WHITC  White Clover Markets
# 2154          98124         USA      WHITC  White Clover Markets
#
#                   CustomerAddress CustomerCity  ... ProductID  \
# 2150  305 - 14th Ave. S. Suite 3B      Seattle  ...        38
# ...

# %%
#muestra la información
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2155 entries, 0 to 2154
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ShipName            2155 non-null   str
#  1   ShipAddress         2155 non-null   str
#  2   ShipCity            2155 non-null   str
#  3   ShipRegion          856 non-null    str
#  4   ShipPostalCode      2100 non-null   str
#  5   ShipCountry         2155 non-null   str
#  6   CustomerID          2155 non-null   str
#  7   CustomerName        2155 non-null   str
#  8   CustomerAddress     2155 non-null   str
#  9   CustomerCity        2155 non-null   str
#  10  CustomerPostalCode  2100 non-null   str
#  11  CustomerCountry     2155 non-null   str
#  12  Salesperson         2155 non-null   str
#  13  OrderID             2155 non-null   int64
#  14  ShipperName         2155 non-null   str
#  15  ProductID           2155 non-null   int64
# ...

# %%
#muestra la metadata del dataFrame
df.shape
# Out:
# (2155, 25)

# %%
#muestra estadística básica
df.describe()
# Out:
#             OrderID    ProductID    UnitPrice     Quantity     Discount  \
# count   2155.000000  2155.000000  2155.000000  2155.000000  2155.000000
# mean   10659.375870    40.793039    26.218520    23.812993     0.056167
# std      241.378032    22.159019    29.827418    19.022047     0.083450
# min    10248.000000     1.000000     2.000000     1.000000     0.000000
# 25%    10451.000000    22.000000    12.000000    10.000000     0.000000
# 50%    10657.000000    41.000000    18.400000    20.000000     0.000000
# 75%    10862.500000    60.000000    32.000000    30.000000     0.100000
# max    11077.000000    77.000000   263.500000   130.000000     0.250000
#
#        ExtendedPrice      Freight
# count    2155.000000  2155.000000
# mean      587.374970    96.197726
# std       969.224236   133.011272
# min         4.800000     0.020000
# 25%       147.000000    19.610000
# 50%       337.750000    53.800000
# 75%       656.000000   120.920000
# max     15810.000000  1007.640000

# %%
#muestra los datos
df.values
# Out:
# array([["Alfred's Futterkiste", 'Obere Str. 57', 'Berlin', ...,
#         '10/3/2017', '10/31/2017', '10/13/2017'],
#        ["Alfred's Futterkiste", 'Obere Str. 57', 'Berlin', ...,
#         '10/13/2017', '11/24/2017', '10/21/2017'],
#        ["Alfred's Futterkiste", 'Obere Str. 57', 'Berlin', ...,
#         '10/13/2017', '11/24/2017', '10/21/2017'],
#        ...,
#        ['White Clover Markets', '1029 - 12th Ave. S.', 'Seattle', ...,
#         '5/1/2018', '5/29/2018', '5/4/2018'],
#        ['White Clover Markets', '1029 - 12th Ave. S.', 'Seattle', ...,
#         '5/1/2018', '5/29/2018', '5/4/2018'],
#        ['White Clover Markets', '1029 - 12th Ave. S.', 'Seattle', ...,
#         '5/1/2018', '5/29/2018', '5/4/2018']],
#       shape=(2155, 25), dtype=object)

# %%
#muestra los nombres de las columnas
df.columns
# Out:
# Index(['ShipName', 'ShipAddress', 'ShipCity', 'ShipRegion', 'ShipPostalCode',
#        'ShipCountry', 'CustomerID', 'CustomerName', 'CustomerAddress',
#        'CustomerCity', 'CustomerPostalCode', 'CustomerCountry', 'Salesperson',
#        'OrderID', 'ShipperName', 'ProductID', 'ProductName', 'UnitPrice',
#        'Quantity', 'Discount', 'ExtendedPrice', 'Freight', 'Order_Date',
#        'Required_Date', 'Shipped_Date'],
#       dtype='str')

# %%
#muetsra el indice
df.index
# Out:
# RangeIndex(start=0, stop=2155, step=1)

# %% [markdown]
# ### 🎯 Selección y Métodos LOC / ILOC
# *Extracción de datos por etiquetas y posiciones.*

# %%
#selección
df['ShipCity']
# Out:
# 0        Berlin
# 1        Berlin
# 2        Berlin
# 3        Berlin
# 4        Berlin
#          ...
# 2150    Seattle
# 2151    Seattle
# 2152    Seattle
# 2153    Seattle
# 2154    Seattle
# Name: ShipCity, Length: 2155, dtype: str

# %%
#validación tipo de datos
type(df['ShipCity'])
# Out:
# pandas.Series

# %%
#selección por indice
df[1:4]
# Out:
#                ShipName    ShipAddress ShipCity ShipRegion ShipPostalCode  \
# 1  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# 2  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# 3  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
#
#   ShipCountry CustomerID         CustomerName CustomerAddress CustomerCity  \
# 1     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 2     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 3     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
#
#    ... ProductID           ProductName UnitPrice  Quantity Discount  \
# 1  ...         3         Aniseed Syrup      10.0         6      0.0
# 2  ...        76          Lakkalikööri      18.0        15      0.0
# 3  ...        59  Raclette Courdavault      55.0        15      0.0
#
#    ExtendedPrice Freight  Order_Date  Required_Date  Shipped_Date
# ...

# %% [markdown]
# ### Método LOC

# %%
#indicar columna ndice
df1 = df.set_index('ShipName')

# %%
#filtrar filas por indice
df2= df1.loc['QUICK-Stop']
df2.head()
# Out:
#                  ShipAddress   ShipCity ShipRegion ShipPostalCode ShipCountry  \
# ShipName
# QUICK-Stop  Taucherstraße 10  Cunewalde        NaN          01307     Germany
# QUICK-Stop  Taucherstraße 10  Cunewalde        NaN          01307     Germany
# QUICK-Stop  Taucherstraße 10  Cunewalde        NaN          01307     Germany
# QUICK-Stop  Taucherstraße 10  Cunewalde        NaN          01307     Germany
# QUICK-Stop  Taucherstraße 10  Cunewalde        NaN          01307     Germany
#
#            CustomerID CustomerName   CustomerAddress CustomerCity  \
# ShipName
# QUICK-Stop      QUICK   QUICK-Stop  Taucherstraße 10    Cunewalde
# QUICK-Stop      QUICK   QUICK-Stop  Taucherstraße 10    Cunewalde
# QUICK-Stop      QUICK   QUICK-Stop  Taucherstraße 10    Cunewalde
# QUICK-Stop      QUICK   QUICK-Stop  Taucherstraße 10    Cunewalde
# QUICK-Stop      QUICK   QUICK-Stop  Taucherstraße 10    Cunewalde
#
#            CustomerPostalCode  ... ProductID                 ProductName  \
# ...

# %%
#seleccionar todas las filas y las columnas específicas
df3 = df.loc[:,['ShipName','ShipperName']]
df3.head()
# Out:
#                ShipName       ShipperName
# 0  Alfred's Futterkiste    United Package
# 1  Alfred's Futterkiste    Speedy Express
# 2  Alfred's Futterkiste    Speedy Express
# 3  Alfred's Futterkiste  Federal Shipping
# 4  Alfred's Futterkiste    Speedy Express

# %%
#reseteando el índice (drop=True elimina los indices repetidos)
df4 = df3.reset_index().sort_index()
df4.head()
# Out:
#    index              ShipName       ShipperName
# 0      0  Alfred's Futterkiste    United Package
# 1      1  Alfred's Futterkiste    Speedy Express
# 2      2  Alfred's Futterkiste    Speedy Express
# 3      3  Alfred's Futterkiste  Federal Shipping
# 4      4  Alfred's Futterkiste    Speedy Express

# %% [markdown]
# ### Método ILOC

# %%
#seleccionar un rango con el indice
df5 = df.iloc[1:100]
df5.head()
# Out:
#                ShipName    ShipAddress ShipCity ShipRegion ShipPostalCode  \
# 1  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# 2  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# 3  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# 4  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# 5  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
#
#   ShipCountry CustomerID         CustomerName CustomerAddress CustomerCity  \
# 1     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 2     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 3     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 4     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 5     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
#
# ...

# %%
#selección de filas exactas
df5 = df.iloc[['100','200']]
df5
# Out:
#                 ShipName           ShipAddress        ShipCity ShipRegion  \
# 100  Lehmanns Marktstand          Magazinweg 7  Frankfurt a.M.        NaN
# 200             Bon app'  12, rue des Bouchers       Marseille        NaN
#
#     ShipPostalCode ShipCountry CustomerID         CustomerName  \
# 100          60528     Germany      LEHMS  Lehmanns Marktstand
# 200          13008      France      BONAP             Bon app'
#
#           CustomerAddress    CustomerCity  ... ProductID       ProductName  \
# 100          Magazinweg 7  Frankfurt a.M.  ...        33           Geitost
# 200  12, rue des Bouchers       Marseille  ...        18  Carnarvon Tigers
#
#     UnitPrice  Quantity Discount  ExtendedPrice Freight  Order_Date  \
# 100       2.5        30      0.0           75.0   58.88   5/14/2017
# 200      50.0        30      0.0         1500.0   64.56   3/11/2017
#
#      Required_Date  Shipped_Date
# 100      6/11/2017      6/6/2017
# 200       4/8/2017     3/14/2017
#
# ...

# %%
#selección de columnas por índice
df5 = df.iloc[:,[0,1]]
df5.head()
# Out:
#                ShipName    ShipAddress
# 0  Alfred's Futterkiste  Obere Str. 57
# 1  Alfred's Futterkiste  Obere Str. 57
# 2  Alfred's Futterkiste  Obere Str. 57
# 3  Alfred's Futterkiste  Obere Str. 57
# 4  Alfred's Futterkiste  Obere Str. 57

# %% [markdown]
# ### 🧪  Filtrado y Ordenamiento
# *Aplicación de operadores lógicos (AND/OR) y sort_values.*

# %%
#filtro con operadores de comparación básicos
df_fil_1 = df[df['ProductID']>50]
df_fil_1.head()
# Out:
#                   ShipName     ShipAddress  ShipCity ShipRegion  \
# 0     Alfred's Futterkiste   Obere Str. 57    Berlin        NaN
# 2     Alfred's Futterkiste   Obere Str. 57    Berlin        NaN
# 3     Alfred's Futterkiste   Obere Str. 57    Berlin        NaN
# 5     Alfred's Futterkiste   Obere Str. 57    Berlin        NaN
# 6  Blauer See Delikatessen  Forsterstr. 57  Mannheim        NaN
#
#   ShipPostalCode ShipCountry CustomerID             CustomerName  \
# 0          12209     Germany      ALFKI      Alfreds Futterkiste
# 2          12209     Germany      ALFKI      Alfreds Futterkiste
# 3          12209     Germany      ALFKI      Alfreds Futterkiste
# 5          12209     Germany      ALFKI      Alfreds Futterkiste
# 6          68306     Germany      BLAUS  Blauer See Delikatessen
#
#   CustomerAddress CustomerCity  ... ProductID           ProductName UnitPrice  \
# 0   Obere Str. 57       Berlin  ...        63          Vegie-spread     43.90
# ...

# %%
#operadores lógicos (and, or, bot, isin)
df_fil_2 = df[(df['ShipName']== 'LILA-Supermercado') & (df['ProductID']== 30)]
df_fil_2.head()
# Out:
#                ShipName                                     ShipAddress  \
# 1401  LILA-Supermercado  Carrera 52 con Ave. Bolívar #65-98 Llano Largo
# 1405  LILA-Supermercado  Carrera 52 con Ave. Bolívar #65-98 Llano Largo
#
#           ShipCity ShipRegion ShipPostalCode ShipCountry CustomerID  \
# 1401  Barquisimeto       Lara           3508   Venezuela      LILAS
# 1405  Barquisimeto       Lara           3508   Venezuela      LILAS
#
#            CustomerName                                 CustomerAddress  \
# 1401  LILA-Supermercado  Carrera 52 con Ave. Bolívar #65-98 Llano Largo
# 1405  LILA-Supermercado  Carrera 52 con Ave. Bolívar #65-98 Llano Largo
#
#       CustomerCity  ... ProductID            ProductName UnitPrice  Quantity  \
# 1401  Barquisimeto  ...        30  Nord-Ost Matjeshering     20.70        28
# 1405  Barquisimeto  ...        30  Nord-Ost Matjeshering     25.89         4
#
#      Discount  ExtendedPrice Freight  Order_Date  Required_Date  Shipped_Date
# ...

# %%
df_fil_3 = df[df['ShipName'].isin(['LILA-Supermercado','Familia Arquibaldo'])]
df_fil_3.head()
# Out:
#                ShipName                                     ShipAddress  \
# 1388  LILA-Supermercado  Carrera 52 con Ave. Bolívar #65-98 Llano Largo
# 1389  LILA-Supermercado  Carrera 52 con Ave. Bolívar #65-98 Llano Largo
# 1390  LILA-Supermercado  Carrera 52 con Ave. Bolívar #65-98 Llano Largo
# 1391  LILA-Supermercado  Carrera 52 con Ave. Bolívar #65-98 Llano Largo
# 1392  LILA-Supermercado  Carrera 52 con Ave. Bolívar #65-98 Llano Largo
#
#           ShipCity ShipRegion ShipPostalCode ShipCountry CustomerID  \
# 1388  Barquisimeto       Lara           3508   Venezuela      LILAS
# 1389  Barquisimeto       Lara           3508   Venezuela      LILAS
# 1390  Barquisimeto       Lara           3508   Venezuela      LILAS
# 1391  Barquisimeto       Lara           3508   Venezuela      LILAS
# 1392  Barquisimeto       Lara           3508   Venezuela      LILAS
#
#            CustomerName                                 CustomerAddress  \
# ...

# %%
#### np.logical_and, np.logical_or, np.logical_not
df_fil_4 = df[np.logical_and(df['ProductID']>=50, df['ProductID']<=60)]
df_fil_4.head()
# Out:
#                    ShipName     ShipAddress  ShipCity ShipRegion  \
# 3      Alfred's Futterkiste   Obere Str. 57    Berlin        NaN
# 6   Blauer See Delikatessen  Forsterstr. 57  Mannheim        NaN
# 8   Blauer See Delikatessen  Forsterstr. 57  Mannheim        NaN
# 16  Blauer See Delikatessen  Forsterstr. 57  Mannheim        NaN
# 18  Blauer See Delikatessen  Forsterstr. 57  Mannheim        NaN
#
#    ShipPostalCode ShipCountry CustomerID             CustomerName  \
# 3           12209     Germany      ALFKI      Alfreds Futterkiste
# 6           68306     Germany      BLAUS  Blauer See Delikatessen
# 8           68306     Germany      BLAUS  Blauer See Delikatessen
# 16          68306     Germany      BLAUS  Blauer See Delikatessen
# 18          68306     Germany      BLAUS  Blauer See Delikatessen
#
#    CustomerAddress CustomerCity  ... ProductID            ProductName  \
# 3    Obere Str. 57       Berlin  ...        59   Raclette Courdavault
# ...

# %% [markdown]
# ### Ordenar el DataFrame

# %%
#ordenar por multiples columnas, descendente y ascendente
sort= df.sort_values(['ProductID','OrderID'], ascending=[False,True])
sort.head()
# Out:
#                     ShipName                                 ShipAddress  \
# 1781  Wellington Importadora                          Rua do Mercado, 12
# 1792        HILARION-Abastos  Carrera 22 con Ave. Carlos Soublette #8-35
# 1681        Comércio Mineiro                        Av. dos Lusíadas, 23
# 698   Galería del gastronómo                      Rambla de Cataluña, 23
# 582             Vaffeljernet                               Smagsloget 45
#
#            ShipCity ShipRegion ShipPostalCode ShipCountry CustomerID  \
# 1781        Resende         SP      08737-363      Brazil      WELLI
# 1792  San Cristóbal    Táchira           5022   Venezuela      HILAA
# 1681      Sao Paulo         SP      05432-043      Brazil      COMMI
# 698       Barcelona        NaN           8022       Spain      GALED
# 582           Århus        NaN           8200     Denmark      VAFFE
#
#                 CustomerName                             CustomerAddress  \
# ...

# %%
#order datos en el indice
sort_1 = df.set_index('ShipName').sort_index()
sort_1.head()
# Out:
#                         ShipAddress ShipCity ShipRegion ShipPostalCode  \
# ShipName
# Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
#
#                      ShipCountry CustomerID         CustomerName  \
# ShipName
# Alfred's Futterkiste     Germany      ALFKI  Alfreds Futterkiste
# Alfred's Futterkiste     Germany      ALFKI  Alfreds Futterkiste
# Alfred's Futterkiste     Germany      ALFKI  Alfreds Futterkiste
# Alfred's Futterkiste     Germany      ALFKI  Alfreds Futterkiste
# Alfred's Futterkiste     Germany      ALFKI  Alfreds Futterkiste
#
#                      CustomerAddress CustomerCity CustomerPostalCode  ...  \
# ...

# %% [markdown]
# #### 🧼 Limpieza de Nulos

# %%
#visualizar cuales columnas tienen valores nulos
df.isna().any()
# Out:
# ShipName              False
# ShipAddress           False
# ShipCity              False
# ShipRegion             True
# ShipPostalCode         True
# ShipCountry           False
# CustomerID            False
# CustomerName          False
# CustomerAddress       False
# CustomerCity          False
# CustomerPostalCode     True
# CustomerCountry       False
# Salesperson           False
# OrderID               False
# ShipperName           False
# ProductID             False
# ProductName           False
# UnitPrice             False
# Quantity              False
# Discount              False
# ExtendedPrice         False
# Freight               False
# Order_Date            False
# Required_Date         False
# Shipped_Date          False
# dtype: bool

# %%
#contando la cantidad de valores vacios
df.isnull().sum()
# Out:
# ShipName                 0
# ShipAddress              0
# ShipCity                 0
# ShipRegion            1299
# ShipPostalCode          55
# ShipCountry              0
# CustomerID               0
# CustomerName             0
# CustomerAddress          0
# CustomerCity             0
# CustomerPostalCode      55
# CustomerCountry          0
# Salesperson              0
# OrderID                  0
# ShipperName              0
# ProductID                0
# ProductName              0
# UnitPrice                0
# Quantity                 0
# Discount                 0
# ExtendedPrice            0
# Freight                  0
# Order_Date               0
# Required_Date            0
# Shipped_Date             0
# dtype: int64

# %%
#eliminar elementos vacios
df_nul = df.dropna()
df_nul.head()
# Out:
#              ShipName                    ShipAddress    ShipCity ShipRegion  \
# 1299  Around the Horn  Brook Farm Stratford St. Mary  Colchester      Essex
# 1300  Around the Horn  Brook Farm Stratford St. Mary  Colchester      Essex
# 1301  Around the Horn  Brook Farm Stratford St. Mary  Colchester      Essex
# 1302  Around the Horn  Brook Farm Stratford St. Mary  Colchester      Essex
# 1303  Around the Horn  Brook Farm Stratford St. Mary  Colchester      Essex
#
#      ShipPostalCode ShipCountry CustomerID     CustomerName  CustomerAddress  \
# 1299        CO7 6JX          UK      AROUT  Around the Horn  120 Hanover Sq.
# 1300        CO7 6JX          UK      AROUT  Around the Horn  120 Hanover Sq.
# 1301        CO7 6JX          UK      AROUT  Around the Horn  120 Hanover Sq.
# 1302        CO7 6JX          UK      AROUT  Around the Horn  120 Hanover Sq.
# 1303        CO7 6JX          UK      AROUT  Around the Horn  120 Hanover Sq.
#
# ...

# %%
#reemplazar valores vacios con 0
df_0 = df.fillna(0)
df_0.head()
# Out:
#                ShipName    ShipAddress ShipCity ShipRegion ShipPostalCode  \
# 0  Alfred's Futterkiste  Obere Str. 57   Berlin          0          12209
# 1  Alfred's Futterkiste  Obere Str. 57   Berlin          0          12209
# 2  Alfred's Futterkiste  Obere Str. 57   Berlin          0          12209
# 3  Alfred's Futterkiste  Obere Str. 57   Berlin          0          12209
# 4  Alfred's Futterkiste  Obere Str. 57   Berlin          0          12209
#
#   ShipCountry CustomerID         CustomerName CustomerAddress CustomerCity  \
# 0     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 1     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 2     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 3     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 4     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
#
# ...

# %%
#reemplazamos 0 a nulos
df_0.replace(0,np.nan, inplace=True)
df_0.head()
# Out:
#                ShipName    ShipAddress ShipCity ShipRegion ShipPostalCode  \
# 0  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# 1  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# 2  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# 3  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
# 4  Alfred's Futterkiste  Obere Str. 57   Berlin        NaN          12209
#
#   ShipCountry CustomerID         CustomerName CustomerAddress CustomerCity  \
# 0     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 1     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 2     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 3     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
# 4     Germany      ALFKI  Alfreds Futterkiste   Obere Str. 57       Berlin
#
# ...

# %% [markdown]
# ### 📊 Agrupación de Datos

# %%
#agrupación básico con una variable y su agregación
df_group = df.groupby('ShipName')['Quantity'].mean()
df_group
# Out:
# ShipName
# Alfred's Futterkiste                  15.111111
# Alfreds Futterkiste                   12.666667
# Ana Trujillo Emparedados y helados     6.300000
# Antonio Moreno Taquería               21.117647
# Around the Horn                       21.666667
#                                         ...
# Wartian Herkku                        19.918919
# Wellington Importadora                14.052632
# White Clover Markets                  26.575000
# Wilman Kala                            8.705882
# Wolski Zajazd                         12.812500
# Name: Quantity, Length: 90, dtype: float64

# %%
#diferentes funciones de agregación  median(), value_counts(normalize = True)
df_group1 = df.groupby('ShipName')['Quantity'].agg([min,max,sum,np.mean])
df_group1.head()
# Out:
#                                     min  max  sum       mean
# ShipName
# Alfred's Futterkiste                  2   40  136  15.111111
# Alfreds Futterkiste                   2   21   38  12.666667
# Ana Trujillo Emparedados y helados    1   10   63   6.300000
# Antonio Moreno Taquería               4   50  359  21.117647
# Around the Horn                       3   50  650  21.666667

# %% [markdown]
# ### 🔄 Tablas Dinámicas (Pivot Tables)

# %%
#agregar una nueva columna calculada
df['SalesAmount']= df['Quantity'] *  df['UnitPrice']

#creando la tabla dinámica
pivot_table = df.pivot_table(
    'SalesAmount', index= 'ShipCountry', columns= 'ShipperName',
    aggfunc=[np.median,np.sum])
pivot_table.head()
# Out:
#                       median                                            sum  \
# ShipperName Federal Shipping Speedy Express United Package Federal Shipping
# ShipCountry
# Argentina              155.0          186.6          180.0          1210.30
# Austria                650.0          600.0          651.0         46566.45
# Belgium                456.0          477.4          420.0         11592.80
# Brazil                 340.0          285.0          341.0         17434.92
# Canada                 315.0          600.0          496.0         20605.50
#
#
# ShipperName Speedy Express United Package
# ShipCountry
# Argentina          1816.20        5092.60
# Austria           45125.33       47804.85
# Belgium            5370.18       18172.00
# Brazil            38308.33       59225.23
# Canada             5777.80       28950.80

# %%
#rellenar los valores vacíos y agregar los totales
pivot_table1 = df.pivot_table(
    'SalesAmount', index= 'ShipCountry', columns= 'ShipperName',
    aggfunc=[np.median,np.sum],fill_value=0, margins= True)
pivot_table1.head()
# Out:
#                       median                                       \
# ShipperName Federal Shipping Speedy Express United Package    All
# ShipCountry
# Argentina              155.0          186.6          180.0  180.0
# Austria                650.0          600.0          651.0  650.0
# Belgium                456.0          477.4          420.0  450.0
# Brazil                 340.0          285.0          341.0  315.0
# Canada                 315.0          600.0          496.0  396.8
#
#                          sum
# ShipperName Federal Shipping Speedy Express United Package        All
# ShipCountry
# Argentina            1210.30        1816.20        5092.60    8119.10
# Austria             46566.45       45125.33       47804.85  139496.63
# Belgium             11592.80        5370.18       18172.00   35134.98
# Brazil              17434.92       38308.33       59225.23  114968.48
# Canada              20605.50        5777.80       28950.80   55334.10

# %% [markdown]
# ### 📅 Trabajo con Fechas (Time Series)
# ### ⚙️ Conversión y Extracción de Tiempo

# %%
dft= pd.read_csv(r'C:\Users\Outlet\Desktop\Nueva carpeta\BDTienda.csv',sep=',',header=0, index_col=False, encoding='latin-1',engine='python')
dft.head()
# Out:
#    Row ID         Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040   1/1/2011  6/1/2011  Standard Class    TB-11280
# 1   22253    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
# 2   48883     HU-2011-1220   1/1/2011  5/1/2011    Second Class      AT-735
# 3   11731  IT-2011-3647632   1/1/2011  5/1/2011    Second Class    EM-14140
# 4   22255    IN-2011-47883   1/1/2011  8/1/2011  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#          Product ID         Category Sub-Category  \
# 0  OFF-TEN-10000025  Office Supplies      Storage
# ...

# %%
#especificar columna como fecha

dft['Order Date'] = pd.to_datetime(dft['Order Date'], dayfirst=True, errors='coerce')
dft['Ship Date'] = pd.to_datetime(dft['Ship Date'], dayfirst=True, errors='coerce')

print(dft[['Order Date', 'Ship Date']].head())
# Out:
#   Order Date  Ship Date
# 0 2011-01-01 2011-01-06
# 1 2011-01-01 2011-01-08
# 2 2011-01-01 2011-01-05
# 3 2011-01-01 2011-01-05
# 4 2011-01-01 2011-01-08

# %%
#personalizar formato de fecha
dft['Order_date'] = dft['Order Date'].dt.strftime('%d-%m-%Y')
dft.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040 2011-01-01 2011-01-06  Standard Class    TB-11280
# 1   22253    IN-2011-47883 2011-01-01 2011-01-08  Standard Class    JH-15985
# 2   48883     HU-2011-1220 2011-01-01 2011-01-05    Second Class      AT-735
# 3   11731  IT-2011-3647632 2011-01-01 2011-01-05    Second Class    EM-14140
# 4   22255    IN-2011-47883 2011-01-01 2011-01-08  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
#
#           Category  Sub-Category                 Product Name    Sales  \
# ...

# %% [markdown]
# ### 🗓️ Análisis de Tendencia Temporal
# *Se realiza un remuestreo (resample) de los datos para analizar el promedio de ventas mensual.*

# %%
#agrupar por fecha
dft.resample('ME', on='Ship Date')['Sales'].mean()
# Out:
# Ship Date
# 2011-01-31    299.744098
# 2011-02-28    201.074138
# 2011-03-31    242.060762
# 2011-04-30    221.290312
# 2011-05-31    216.135187
# 2011-06-30    261.364082
# 2011-07-31    211.093045
# 2011-08-31    220.232526
# 2011-09-30    288.716858
# 2011-10-31    253.824563
# 2011-11-30    270.258058
# 2011-12-31    241.491636
# 2012-01-31    214.424670
# 2012-02-29    271.907393
# 2012-03-31    246.808989
# 2012-04-30    209.978539
# 2012-05-31    230.430297
# 2012-06-30    218.675591
# 2012-07-31    236.799975
# 2012-08-31    270.621560
# 2012-09-30    257.495327
# 2012-10-31    251.648860
# 2012-11-30    233.038179
# 2012-12-31    254.904948
# 2013-01-31    285.488618
# 2013-02-28    288.837431
# 2013-03-31    309.381249
# 2013-04-30    227.465380
# 2013-05-31    222.692351
# 2013-06-30    281.857200
# 2013-07-31    267.072241
# 2013-08-31    210.101252
# 2013-09-30    210.542007
# 2013-10-31    284.447682
# 2013-11-30    210.385727
# 2013-12-31    266.510325
# ...

# %%
#extrayendo datos a partir de fechas
#nombre del día
dft['dia'] = pd.to_datetime(dft['Ship Date']).dt.day_name()

#año
dft['anio'] = pd.to_datetime(dft['Ship Date']).dt.year

#mes
dft['mes'] = pd.to_datetime(dft['Ship Date']).dt.month_name()

dft.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040 2011-01-01 2011-01-06  Standard Class    TB-11280
# 1   22253    IN-2011-47883 2011-01-01 2011-01-08  Standard Class    JH-15985
# 2   48883     HU-2011-1220 2011-01-01 2011-01-05    Second Class      AT-735
# 3   11731  IT-2011-3647632 2011-01-01 2011-01-05    Second Class    EM-14140
# 4   22255    IN-2011-47883 2011-01-01 2011-01-08  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...    Sales  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...  408.300
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...  120.366
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...   66.120
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...   44.865
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...  113.670
#
# ...

# %% [markdown]
# ### 🔗  Uniones-Concat

# %%
ap1= pd.read_csv(r'C:\Users\Outlet\Desktop\Nueva carpeta\vta_2013.csv',sep=',',header=0, index_col=False, encoding='latin-1',engine='python')
ap2= pd.read_csv(r'C:\Users\Outlet\Desktop\Nueva carpeta\vta_2014.csv',sep=',',header=0, index_col=False, encoding='latin-1',engine='python')

# %%
#concatenar a nivel fila
ap3 = pd.concat([ap1, ap2],ignore_index =True, axis=0)
ap3.head()
# Out:
#    Row ID       Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 0   22265  ID-2013-37383   1/1/2013  4/1/2013     First Class    MY-18295
# 1   22618  IN-2013-47960   1/1/2013  6/1/2013  Standard Class    JE-15715
# 2   22268  ID-2013-37383   1/1/2013  4/1/2013     First Class    MY-18295
# 3   22615  IN-2013-47960   1/1/2013  6/1/2013  Standard Class    JE-15715
# 4   22617  IN-2013-47960   1/1/2013  6/1/2013  Standard Class    JE-15715
#
#      Customer Name    Segment     City            State  ...       Product ID  \
# 0  Muhammed Yedwab  Corporate   Albury  New South Wales  ...  TEC-CO-10002379
# 1       Joe Elijah   Consumer  Tianjin          Tianjin  ...  FUR-BO-10003549
# 2  Muhammed Yedwab  Corporate   Albury  New South Wales  ...  TEC-AC-10001500
# 3       Joe Elijah   Consumer  Tianjin          Tianjin  ...  FUR-BO-10004541
# 4       Joe Elijah   Consumer  Tianjin          Tianjin  ...  FUR-BO-10003661
#
# ...

# %% [markdown]
# ### 🧬  Tipos de Datos y Cambio de Tipos de Datos (Coerción)

# %%
ap3.dtypes
# Out:
# Row ID              int64
# Order ID              str
# Order Date            str
# Ship Date             str
# Ship Mode             str
# Customer ID           str
# Customer Name         str
# Segment               str
# City                  str
# State                 str
# Country               str
# Postal Code       float64
# Market                str
# Region                str
# Product ID            str
# Category              str
# Sub-Category          str
# Product Name          str
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Shipping Cost     float64
# Order Priority        str
# dtype: object

# %%
#cambiar formato fecha
ap3['Order Date'] = pd.to_datetime(ap3['Order Date'], dayfirst=True,format='mixed')
ap3['Ship Date'] = pd.to_datetime(ap3['Ship Date'], dayfirst=True,format='mixed')

#cambiar a texto para que no tenga decimales
ap3['Postal Code'] = ap3['Postal Code'].astype(str)

print(ap3.dtypes)
# Out:
# Row ID                     int64
# Order ID                     str
# Order Date        datetime64[us]
# Ship Date         datetime64[us]
# Ship Mode                    str
# Customer ID                  str
# Customer Name                str
# Segment                      str
# City                         str
# State                        str
# Country                      str
# Postal Code                  str
# Market                       str
# Region                       str
# Product ID                   str
# Category                     str
# Sub-Category                 str
# Product Name                 str
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority               str
# dtype: object

# %% [markdown]
# ### 👯  Eliminación de Duplicados

# %%
#ver si hay duplicados
print("Cantidad de filas repetidas:")
print(ap3.duplicated().sum())
# Out:
# Cantidad de filas repetidas:
# 0

# %% [markdown]
# ### ✍️ Limpieza de Espacios

# %%
#corregir espacios en blanco
dft['Customer Name'] = dft['Customer Name'].str.strip()
